# %%
import numpy as np
import pandas as pd

import datetime as dt

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
# Classifier Libraries
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix, recall_score, classification_report
from xgboost import XGBClassifier, plot_importance
from sklearn.metrics import accuracy_score, precision_recall_curve

# %%
df_cust = pd.read_csv('customer.csv')
print(df_cust.shape)
df_cust.head()
# Out:
# (1000, 8)
#    CUSTOMER_ID  x_customer_id  y_customer_id  mean_amount  std_amount  \
# 0            0      54.881350      71.518937    62.262521   31.131260
# 1            1      42.365480      64.589411    46.570785   23.285393
# 2            2      96.366276      38.344152    80.213879   40.106939
# 3            3      56.804456      92.559664    11.748426    5.874213
# 4            4       2.021840      83.261985    78.924891   39.462446
#
#    mean_nb_tx_per_day                                available_terminals  \
# 0            2.179533  [29, 87, 144, 241, 330, 858, 996, 1028, 1067, ...
# 1            3.567092  [5, 160, 242, 378, 431, 475, 571, 762, 876, 93...
# 2            2.115580  [316, 406, 447, 523, 968, 1200, 1318, 1365, 16...
# 3            0.348517  [65, 94, 113, 364, 401, 433, 485, 651, 672, 77...
# 4            3.480049      [372, 614, 774, 1362, 1446, 1564, 1637, 1939]
#
#    nb_terminals
# 0            22
# 1            20
# 2            10
# 3            17
# 4             8

# %%
df_ter = pd.read_csv('terminal.csv')
print(df_ter.shape)
df_ter.head()
# Out:
# (2000, 3)
#    TERMINAL_ID  x_terminal_id  y_terminal_id
# 0            0      41.702200      72.032449
# 1            1       0.011437      30.233257
# 2            2      14.675589       9.233859
# 3            3      18.626021      34.556073
# 4            4      39.676747      53.881673

# %%
df_train = pd.read_csv('train.csv', parse_dates=["TX_DATETIME"])
print(df_train.shape)
df_train.head()
# Out:
# (291231, 6)
#    TRANSACTION_ID         TX_DATETIME  CUSTOMER_ID  TERMINAL_ID  TX_AMOUNT  \
# 0           59383 2021-08-01 00:04:37          323          217       4.60
# 1           59384 2021-08-01 00:12:10            6          429       8.61
# 2           59385 2021-08-01 00:12:34          714         1011      64.00
# 3           59386 2021-08-01 00:15:40          266         1969      12.72
# 4           59387 2021-08-01 00:16:01          890         1482      98.88
#
#    TX_FRAUD
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
df_train['Year'] = df_train['TX_DATETIME'].dt.year
df_train['Month'] = df_train['TX_DATETIME'].dt.month
df_train['Day'] = df_train['TX_DATETIME'].dt.day
df_train['Hour'] = df_train['TX_DATETIME'].dt.hour
df_train['Minute'] = df_train['TX_DATETIME'].dt.minute
# df_train['Second'] = df_train['TX_DATETIME'].dt.second
df_train['Quarter'] = df_train['TX_DATETIME'].dt.quarter
df_train['Day_of_week'] = df_train['TX_DATETIME'].dt.dayofweek

# %%
df_train[df_train["TX_FRAUD"]==1] #fraudulent
# Out:
#         TRANSACTION_ID         TX_DATETIME  CUSTOMER_ID  TERMINAL_ID  \
# 8                59391 2021-08-01 00:32:04          220          828
# 268              59651 2021-08-01 06:29:19           74          531
# 327              59710 2021-08-01 07:01:39          580         1084
# 346              59729 2021-08-01 07:16:18          975          423
# 413              59796 2021-08-01 07:48:07          679         1893
# ...                ...                 ...          ...          ...
# 291073          350456 2021-12-30 19:30:45          311          895
# 291113          350496 2021-12-30 20:06:08          359         1193
# 291155          350538 2021-12-30 21:04:38          764          144
# 291165          350548 2021-12-30 21:23:21            2         1365
# 291189          350572 2021-12-30 22:02:00          723         1565
#
#         TX_AMOUNT  TX_FRAUD  Year  Month  Day  Hour  Minute  Quarter  \
# 8           76.25         1  2021      8    1     0      32        3
# 268        228.58         1  2021      8    1     6      29        3
# 327         71.79         1  2021      8    1     7       1        3
# 346         36.26         1  2021      8    1     7      16        3
# 413         38.80         1  2021      8    1     7      48        3
# ...           ...       ...   ...    ...  ...   ...     ...      ...
# 291073      60.12         1  2021     12   30    19      30        4
# 291113      62.77         1  2021     12   30    20       6        4
# 291155      10.36         1  2021     12   30    21       4        4
# 291165      94.92         1  2021     12   30    21      23        4
# 291189      84.04         1  2021     12   30    22       2        4
#
#         Day_of_week
# 8                 6
# 268               6
# 327               6
# 346               6
# 413               6
# ...             ...
# 291073            3
# 291113            3
# 291155            3
# 291165            3
# 291189            3
#
# [6582 rows x 13 columns]

# %%
df_train[df_train["TX_FRAUD"]==0] #legitimate
# Out:
#         TRANSACTION_ID         TX_DATETIME  CUSTOMER_ID  TERMINAL_ID  \
# 0                59383 2021-08-01 00:04:37          323          217
# 1                59384 2021-08-01 00:12:10            6          429
# 2                59385 2021-08-01 00:12:34          714         1011
# 3                59386 2021-08-01 00:15:40          266         1969
# 4                59387 2021-08-01 00:16:01          890         1482
# ...                ...                 ...          ...          ...
# 291226          350609 2021-12-30 23:33:02          221           41
# 291227          350610 2021-12-30 23:46:15          101          761
# 291228          350611 2021-12-30 23:54:38            7         1991
# 291229          350612 2021-12-30 23:56:36          161         1166
# 291230          350613 2021-12-30 23:58:21          618         1549
#
#         TX_AMOUNT  TX_FRAUD  Year  Month  Day  Hour  Minute  Quarter  \
# 0            4.60         0  2021      8    1     0       4        3
# 1            8.61         0  2021      8    1     0      12        3
# 2           64.00         0  2021      8    1     0      12        3
# 3           12.72         0  2021      8    1     0      15        3
# 4           98.88         0  2021      8    1     0      16        3
# ...           ...       ...   ...    ...  ...   ...     ...      ...
# 291226      61.26         0  2021     12   30    23      33        4
# 291227      58.80         0  2021     12   30    23      46        4
# 291228      15.08         0  2021     12   30    23      54        4
# 291229      54.24         0  2021     12   30    23      56        4
# 291230       6.62         0  2021     12   30    23      58        4
#
#         Day_of_week
# 0                 6
# 1                 6
# 2                 6
# 3                 6
# 4                 6
# ...             ...
# 291226            3
# 291227            3
# 291228            3
# 291229            3
# 291230            3
#
# [284649 rows x 13 columns]

# %%
df_train_merge = pd.merge(df_train, df_cust, left_on='CUSTOMER_ID', right_on='CUSTOMER_ID')
df_train_merge
# Out:
#         TRANSACTION_ID         TX_DATETIME  CUSTOMER_ID  TERMINAL_ID  \
# 0                59383 2021-08-01 00:04:37          323          217
# 1                59384 2021-08-01 00:12:10            6          429
# 2                59385 2021-08-01 00:12:34          714         1011
# 3                59386 2021-08-01 00:15:40          266         1969
# 4                59387 2021-08-01 00:16:01          890         1482
# ...                ...                 ...          ...          ...
# 291226          350609 2021-12-30 23:33:02          221           41
# 291227          350610 2021-12-30 23:46:15          101          761
# 291228          350611 2021-12-30 23:54:38            7         1991
# 291229          350612 2021-12-30 23:56:36          161         1166
# 291230          350613 2021-12-30 23:58:21          618         1549
#
#         TX_AMOUNT  TX_FRAUD  Year  Month  Day  Hour  Minute  Quarter  \
# 0            4.60         0  2021      8    1     0       4        3
# 1            8.61         0  2021      8    1     0      12        3
# 2           64.00         0  2021      8    1     0      12        3
# 3           12.72         0  2021      8    1     0      15        3
# 4           98.88         0  2021      8    1     0      16        3
# ...           ...       ...   ...    ...  ...   ...     ...      ...
# 291226      61.26         0  2021     12   30    23      33        4
# 291227      58.80         0  2021     12   30    23      46        4
# 291228      15.08         0  2021     12   30    23      54        4
# 291229      54.24         0  2021     12   30    23      56        4
# 291230       6.62         0  2021     12   30    23      58        4
#
#         Day_of_week  x_customer_id  y_customer_id  mean_amount  std_amount  \
# 0                 6      84.515409      38.276422     7.353061    3.676530
# 1                 6      11.827443      63.992102    18.618562    9.309281
# 2                 6      75.221083      94.991427    82.620413   41.310207
# 3                 6      51.122179       8.329098     9.852171    4.926085
# 4                 6      62.777887      31.405270    83.660035   41.830018
# ...             ...            ...            ...          ...         ...
# 291226            3      79.559037      34.453046    78.232912   39.116456
# 291227            3      86.948853      45.416240    36.036584   18.018292
# 291228            3      52.184832      41.466194    30.132783   15.066392
# 291229            3      38.033518      14.780868    70.068772   35.034386
# 291230            3      96.673774      53.470817     7.338380    3.669190
#
#         mean_nb_tx_per_day                                available_terminals  \
# 0                 3.324124  [51, 68, 208, 217, 293, 353, 534, 717, 773, 86...
# 1                 3.778676  [163, 172, 205, 429, 468, 607, 750, 786, 881, ...
# 2                 3.723765  [58, 799, 1011, 1021, 1228, 1347, 1443, 1462, ...
# 3                 3.862067  [27, 493, 584, 734, 820, 917, 1108, 1363, 1444...
# 4                 3.128315  [154, 177, 351, 444, 633, 739, 1018, 1056, 113...
# ...                    ...                                                ...
# 291226            2.943576  [41, 68, 207, 232, 273, 293, 441, 695, 696, 70...
# 291227            0.930977  [208, 353, 357, 373, 457, 524, 534, 537, 761, ...
# 291228            3.096935  [563, 612, 700, 705, 859, 1036, 1231, 1442, 14...
# 291229            2.627048  [37, 325, 408, 440, 598, 655, 724, 806, 1034, ...
# 291230            2.479088  [16, 100, 183, 549, 698, 747, 989, 1129, 1250,...
#
#         nb_terminals
# 0                 19
# 1                 16
# 2                 13
# 3                 15
# 4                 20
# ...              ...
# 291226            14
# 291227            17
# 291228            15
# 291229            14
# 291230            21
#
# [291231 rows x 20 columns]

# %%
df_train_merge = pd.merge(df_train_merge, df_ter, left_on='TERMINAL_ID', right_on='TERMINAL_ID')
df_train_merge
# Out:
#         TRANSACTION_ID         TX_DATETIME  CUSTOMER_ID  TERMINAL_ID  \
# 0                59383 2021-08-01 00:04:37          323          217
# 1                59384 2021-08-01 00:12:10            6          429
# 2                59385 2021-08-01 00:12:34          714         1011
# 3                59386 2021-08-01 00:15:40          266         1969
# 4                59387 2021-08-01 00:16:01          890         1482
# ...                ...                 ...          ...          ...
# 291226          350609 2021-12-30 23:33:02          221           41
# 291227          350610 2021-12-30 23:46:15          101          761
# 291228          350611 2021-12-30 23:54:38            7         1991
# 291229          350612 2021-12-30 23:56:36          161         1166
# 291230          350613 2021-12-30 23:58:21          618         1549
#
#         TX_AMOUNT  TX_FRAUD  Year  Month  Day  Hour  ...  Day_of_week  \
# 0            4.60         0  2021      8    1     0  ...            6
# 1            8.61         0  2021      8    1     0  ...            6
# 2           64.00         0  2021      8    1     0  ...            6
# 3           12.72         0  2021      8    1     0  ...            6
# 4           98.88         0  2021      8    1     0  ...            6
# ...           ...       ...   ...    ...  ...   ...  ...          ...
# 291226      61.26         0  2021     12   30    23  ...            3
# 291227      58.80         0  2021     12   30    23  ...            3
# 291228      15.08         0  2021     12   30    23  ...            3
# 291229      54.24         0  2021     12   30    23  ...            3
# 291230       6.62         0  2021     12   30    23  ...            3
#
#         x_customer_id  y_customer_id  mean_amount  std_amount  \
# 0           84.515409      38.276422     7.353061    3.676530
# 1           11.827443      63.992102    18.618562    9.309281
# 2           75.221083      94.991427    82.620413   41.310207
# 3           51.122179       8.329098     9.852171    4.926085
# 4           62.777887      31.405270    83.660035   41.830018
# ...               ...            ...          ...         ...
# 291226      79.559037      34.453046    78.232912   39.116456
# 291227      86.948853      45.416240    36.036584   18.018292
# 291228      52.184832      41.466194    30.132783   15.066392
# 291229      38.033518      14.780868    70.068772   35.034386
# 291230      96.673774      53.470817     7.338380    3.669190
#
#         mean_nb_tx_per_day                                available_terminals  \
# 0                 3.324124  [51, 68, 208, 217, 293, 353, 534, 717, 773, 86...
# 1                 3.778676  [163, 172, 205, 429, 468, 607, 750, 786, 881, ...
# 2                 3.723765  [58, 799, 1011, 1021, 1228, 1347, 1443, 1462, ...
# 3                 3.862067  [27, 493, 584, 734, 820, 917, 1108, 1363, 1444...
# 4                 3.128315  [154, 177, 351, 444, 633, 739, 1018, 1056, 113...
# ...                    ...                                                ...
# 291226            2.943576  [41, 68, 207, 232, 273, 293, 441, 695, 696, 70...
# 291227            0.930977  [208, 353, 357, 373, 457, 524, 534, 537, 761, ...
# 291228            3.096935  [563, 612, 700, 705, 859, 1036, 1231, 1442, 14...
# 291229            2.627048  [37, 325, 408, 440, 598, 655, 724, 806, 1034, ...
# 291230            2.479088  [16, 100, 183, 549, 698, 747, 989, 1129, 1250,...
#
#         nb_terminals x_terminal_id  y_terminal_id
# 0                 19     80.316334      40.239252
# 1                 16     15.172487      63.912685
# 2                 13     74.196424      98.288079
# 3                 15     51.950635       6.563484
# 4                 20     62.417972      26.483666
# ...              ...           ...            ...
# 291226            14     75.094243      34.889834
# 291227            17     84.993054      43.465479
# 291228            15     51.314901      42.942203
# 291229            14     38.411423      14.674793
# 291230            21     95.601958      56.461010
#
# [291231 rows x 22 columns]

# %%
corr = df_train_merge.corr(numeric_only=True) 

#make the heatmap larger in size
# plt.figure(figsize = (7,7))
plt.figure(figsize = (17,17))

sns.heatmap(corr, annot=True)
plt.show()

# %%
df_train_merge.describe()
# Out:
#        TRANSACTION_ID                    TX_DATETIME    CUSTOMER_ID  \
# count   291231.000000                         291231  291231.000000
# mean    204998.000000  2021-10-16 02:06:44.044813056     496.256202
# min      59383.000000            2021-08-01 00:04:37       0.000000
# 25%     132190.500000     2021-09-08 05:17:43.500000     249.000000
# 50%     204998.000000            2021-10-16 05:55:26     498.000000
# 75%     277805.500000     2021-11-23 06:15:18.500000     741.000000
# max     350613.000000            2021-12-30 23:58:21     999.000000
# std      84071.292461                            NaN     285.274966
#
#          TERMINAL_ID      TX_AMOUNT       TX_FRAUD      Year          Month  \
# count  291231.000000  291231.000000  291231.000000  291231.0  291231.000000
# mean      993.718526      53.182274       0.022601    2021.0       9.989053
# min         0.000000       0.000000       0.000000    2021.0       8.000000
# 25%       496.000000      21.130000       0.000000    2021.0       9.000000
# 50%      1000.000000      44.770000       0.000000    2021.0      10.000000
# 75%      1483.000000      76.850000       0.000000    2021.0      11.000000
# max      1999.000000     291.150000       1.000000    2021.0      12.000000
# std       575.267551      39.573329       0.148627       0.0       1.413751
#
#                  Day           Hour  ...        Quarter    Day_of_week  \
# count  291231.000000  291231.000000  ...  291231.000000  291231.000000
# mean       15.723488      11.507707  ...       3.599030       2.976246
# min         1.000000       0.000000  ...       3.000000       0.000000
# 25%         8.000000       8.000000  ...       3.000000       1.000000
# 50%        16.000000      11.000000  ...       4.000000       3.000000
# 75%        23.000000      15.000000  ...       4.000000       5.000000
# max        31.000000      23.000000  ...       4.000000       6.000000
# std         8.776079       5.059829  ...       0.490096       2.002988
#
#        x_customer_id  y_customer_id    mean_amount     std_amount  \
# count  291231.000000  291231.000000  291231.000000  291231.000000
# mean       50.184880      50.429252      51.710394      25.855197
# min         0.007245       0.036734       5.063101       2.531550
# 25%        25.868407      27.459470      28.606102      14.303051
# 50%        48.968491      49.236141      51.641807      25.820903
# 75%        74.735746      75.945025      75.288972      37.644486
# max        99.994897      99.996402      99.981815      49.990907
# std        28.732398      28.416998      27.475610      13.737805
#
#        mean_nb_tx_per_day   nb_terminals  x_terminal_id  y_terminal_id
# count       291231.000000  291231.000000  291231.000000  291231.000000
# mean             2.650934      15.300318      50.218904      50.392889
# min              0.018782       2.000000       0.011437       0.009695
# 25%              1.956902      12.000000      25.983398      27.692306
# 50%              2.836935      15.000000      49.264044      49.074012
# 75%              3.438147      18.000000      75.012425      75.563328
# max              3.999725      28.000000      99.859909      99.987579
# std              0.961907       4.190001      28.682009      28.376333
#
# [8 rows x 21 columns]

# %%
class_names = {0:'Not Fraud', 1:'Fraud'}
print( df_train_merge.TX_FRAUD.value_counts().rename(index = class_names) )
# Out:
# TX_FRAUD
# Not Fraud    284649
# Fraud          6582
# Name: count, dtype: int64

# %%
x = df_train_merge.drop('TX_FRAUD', axis='columns')

x = x.drop('TRANSACTION_ID', axis='columns')
x = x.drop('TX_DATETIME', axis='columns')
x = x.drop('available_terminals', axis='columns')

x = x.drop('mean_amount', axis='columns')
x = x.drop('std_amount', axis='columns')


y = df_train_merge['TX_FRAUD']
x
# Out:
#         CUSTOMER_ID  TERMINAL_ID  TX_AMOUNT  Year  Month  Day  Hour  Minute  \
# 0               323          217       4.60  2021      8    1     0       4
# 1                 6          429       8.61  2021      8    1     0      12
# 2               714         1011      64.00  2021      8    1     0      12
# 3               266         1969      12.72  2021      8    1     0      15
# 4               890         1482      98.88  2021      8    1     0      16
# ...             ...          ...        ...   ...    ...  ...   ...     ...
# 291226          221           41      61.26  2021     12   30    23      33
# 291227          101          761      58.80  2021     12   30    23      46
# 291228            7         1991      15.08  2021     12   30    23      54
# 291229          161         1166      54.24  2021     12   30    23      56
# 291230          618         1549       6.62  2021     12   30    23      58
#
#         Quarter  Day_of_week  x_customer_id  y_customer_id  \
# 0             3            6      84.515409      38.276422
# 1             3            6      11.827443      63.992102
# 2             3            6      75.221083      94.991427
# 3             3            6      51.122179       8.329098
# 4             3            6      62.777887      31.405270
# ...         ...          ...            ...            ...
# 291226        4            3      79.559037      34.453046
# 291227        4            3      86.948853      45.416240
# 291228        4            3      52.184832      41.466194
# 291229        4            3      38.033518      14.780868
# 291230        4            3      96.673774      53.470817
#
#         mean_nb_tx_per_day  nb_terminals  x_terminal_id  y_terminal_id
# 0                 3.324124            19      80.316334      40.239252
# 1                 3.778676            16      15.172487      63.912685
# 2                 3.723765            13      74.196424      98.288079
# 3                 3.862067            15      51.950635       6.563484
# 4                 3.128315            20      62.417972      26.483666
# ...                    ...           ...            ...            ...
# 291226            2.943576            14      75.094243      34.889834
# 291227            0.930977            17      84.993054      43.465479
# 291228            3.096935            15      51.314901      42.942203
# 291229            2.627048            14      38.411423      14.674793
# 291230            2.479088            21      95.601958      56.461010
#
# [291231 rows x 16 columns]

# %%
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.1)
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.001)
# x_train, x_test, y_train, y_test = train_test_split(data_features, data_target, train_size=0.70, test_size=0.30, random_state=1)
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size=0.80, test_size=0.20, random_state=1)

print("Length of x_train is: {x_train}".format(x_train = len(x_train)))
print("Length of x_test is: {x_test}".format(x_test = len(x_test)))
print("Length of y_train is: {y_train}".format(y_train = len(y_train)))
print("Length of y_test is: {y_test}".format(y_test = len(y_test)))
# Out:
# Length of x_train is: 232984
# Length of x_test is: 58247
# Length of y_train is: 232984
# Length of y_test is: 58247

# %%
x_train
# Out:
#         CUSTOMER_ID  TERMINAL_ID  TX_AMOUNT  Year  Month  Day  Hour  Minute  \
# 249665          811          279      39.14  2021     12    9     8      50
# 175801          575          300      44.15  2021     10   31    19      23
# 149883          613         1158     126.97  2021     10   18    10      52
# 285404          674         1330      73.09  2021     12   27    20      31
# 251375          720         1482     127.99  2021     12   10     7      15
# ...             ...          ...        ...   ...    ...  ...   ...     ...
# 21440           917         1104      87.57  2021      8   12     8      30
# 117583          202         1130      28.67  2021     10    1    10      44
# 73349           137         1298      55.07  2021      9    8    10      26
# 267336          761         1099      86.02  2021     12   18    12      20
# 128037          900          850      77.07  2021     10    6    17      47
#
#         Quarter  Day_of_week  x_customer_id  y_customer_id  \
# 249665        4            3      74.738178      15.570077
# 175801        4            6      68.232658      80.570234
# 149883        4            0      86.758085      31.309888
# 285404        4            0      33.758138      60.916405
# 251375        4            4      63.288532      26.646128
# ...         ...          ...            ...            ...
# 21440         3            3      48.949721      77.939096
# 117583        4            4      89.754276      76.996719
# 73349         3            2      50.980720      33.396487
# 267336        4            5      26.054764      55.994741
# 128037        4            2      25.746648      95.859445
#
#         mean_nb_tx_per_day  nb_terminals  x_terminal_id  y_terminal_id
# 249665            3.749174            12      77.014996      13.033578
# 175801            1.689630            13      67.456402      79.977654
# 149883            1.706286            15      85.405979      27.084491
# 285404            0.304581            13      30.803699      58.696221
# 251375            3.043768            21      62.417972      26.483666
# ...                    ...           ...            ...            ...
# 21440             3.903215            21      49.756438      82.117696
# 117583            2.486662            13      92.310068      74.616014
# 73349             0.388972            23      52.716018      28.807959
# 267336            1.783891            16      29.299788      57.749068
# 128037            2.896914            18      25.789298      93.444549
#
# [232984 rows x 16 columns]

# %%
y_train
# Out:
# 249665    0
# 175801    0
# 149883    0
# 285404    0
# 251375    0
#          ..
# 21440     0
# 117583    0
# 73349     0
# 267336    0
# 128037    0
# Name: TX_FRAUD, Length: 232984, dtype: int64

# %%
x_test
# Out:
#         CUSTOMER_ID  TERMINAL_ID  TX_AMOUNT  Year  Month  Day  Hour  Minute  \
# 136825          743         1647      10.43  2021     10   11    11      48
# 202454          505          879      42.23  2021     11   14    18      16
# 36366            95         1516      70.58  2021      8   20     2      59
# 220554          733          503     138.11  2021     11   24     7      49
# 109088          515          637      44.85  2021      9   26    23      43
# ...             ...          ...        ...   ...    ...  ...   ...     ...
# 34041           923          708      15.13  2021      8   18    17      26
# 91655           638           12      23.33  2021      9   17    18      21
# 163962          154          547      19.80  2021     10   25    16       2
# 193945           75         1862      16.24  2021     11   10    11      21
# 213946          403          134      23.52  2021     11   20    16      32
#
#         Quarter  Day_of_week  x_customer_id  y_customer_id  \
# 136825        4            0      36.504355      26.768404
# 202454        4            6       3.521980      18.066062
# 36366         3            4      85.772264      45.722345
# 220554        4            2       4.238788      30.115520
# 109088        3            6      39.362975      37.554936
# ...         ...          ...            ...            ...
# 34041         3            2      95.019247      99.449593
# 91655         3            4      88.382545      85.344933
# 163962        4            0      59.102690      65.917647
# 193945        4            2      90.655550      77.404733
# 213946        4            5      38.306636      39.312242
#
#         mean_nb_tx_per_day  nb_terminals  x_terminal_id  y_terminal_id
# 136825            1.122826            17      31.991506      28.624779
# 202454            2.309985            18       4.939638      15.045503
# 36366             2.303005            19      84.217912      42.461271
# 220554            2.638782            12       4.147508      32.182880
# 109088            2.671908            10      42.879516      38.210064
# ...                    ...           ...            ...            ...
# 34041             1.842709             6      95.739493      95.947061
# 91655             3.028519            15      87.638915      89.460666
# 163962            3.997112            15      59.898529      61.570429
# 193945            0.324406            14      93.348046      80.832697
# 213946            3.526269            12      38.210275      41.081135
#
# [58247 rows x 16 columns]

# %%
y_test
# Out:
# 136825    0
# 202454    0
# 36366     0
# 220554    0
# 109088    0
#          ..
# 34041     0
# 91655     0
# 163962    0
# 193945    0
# 213946    0
# Name: TX_FRAUD, Length: 58247, dtype: int64

# %%
model = LogisticRegression(max_iter=3000)
model.fit(x_train, y_train.values.ravel())
# Out:
# LogisticRegression(max_iter=3000)

# %%
import joblib

# save the model to disk
filename = 'C:/dataset/finalized_model.sav'
joblib.dump(model, filename)
# Out:
# ['C:/dataset/finalized_model.sav']

# %%
# model = XGBClassifier()
# model.fit(x_train,y_train)

# %%
# model.save_model("C:/dataset/model_LogisticRegression_001.json");

# %%
# model = XGBClassifier()
# model.load_model("C:/dataset/model_XGBClassifier_001.json");

# %%
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     56924
#            1       0.00      0.00      0.00      1323
#
#     accuracy                           0.98     58247
#    macro avg       0.49      0.50      0.49     58247
# weighted avg       0.96      0.98      0.97     58247
# c:\Program Files\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Program Files\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Program Files\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Accuracy
accuracy_score(y_pred, y_test)
# Out:
# 0.9772863838480952

# %%
from sklearn import metrics  
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.022713616151904818
# Mean Squared Error: 0.022713616151904818
# Root Mean Squared Error: 0.15071037174628962

# %%
confusion_m = confusion_matrix(y_test, y_pred)
confusion_m
# Out:
# array([[56924,     0],
#        [ 1323,     0]], dtype=int64)

# %%
sns.heatmap(confusion_m, annot=True, linecolor='white', linewidths=1)
# Out:
# <Axes: >

# %%
# plot_importance(model)
# plt.show()

# %%
ytrain_pred = model.predict(x_train)
print(classification_report(y_train, ytrain_pred))
# Out:
# c:\Program Files\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99    227725
#            1       0.00      0.00      0.00      5259
#
#     accuracy                           0.98    232984
#    macro avg       0.49      0.50      0.49    232984
# weighted avg       0.96      0.98      0.97    232984
# c:\Program Files\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Program Files\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
ytrain_pred
ytrain_pred_df = pd.DataFrame(ytrain_pred, columns=['TX_FRAUD'])
ytrain_pred_df
# Out:
#         TX_FRAUD
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 232979         0
# 232980         0
# 232981         0
# 232982         0
# 232983         0
#
# [232984 rows x 1 columns]

# %%
class_names = {0:'Not Fraud', 1:'Fraud'}
print( ytrain_pred_df.TX_FRAUD.value_counts().rename(index = class_names) )
# Out:
# TX_FRAUD
# Not Fraud    232984
# Name: count, dtype: int64

# %% [markdown]
# =====================================================================================================

# %%
df_test = pd.read_csv('test.csv')
print(df_test.shape)
df_test.head()
# Out:
# (226731, 5)
#    TRANSACTION_ID          TX_DATETIME  CUSTOMER_ID  TERMINAL_ID  TX_AMOUNT
# 0          352590  2022-01-01 00:03:14          208          640     147.24
# 1          352591  2022-01-01 00:26:39          851          315      13.27
# 2          352592  2022-01-01 00:30:30          454           27      70.52
# 3          352593  2022-01-01 00:31:31          677         1573      44.75
# 4          352594  2022-01-01 00:56:18          322         1398      37.60

# %%
df_test_merge = pd.merge(df_test, df_cust, left_on='CUSTOMER_ID', right_on='CUSTOMER_ID')
df_test_merge
# Out:
#         TRANSACTION_ID          TX_DATETIME  CUSTOMER_ID  TERMINAL_ID  \
# 0               352590  2022-01-01 00:03:14          208          640
# 1               352591  2022-01-01 00:26:39          851          315
# 2               352592  2022-01-01 00:30:30          454           27
# 3               352593  2022-01-01 00:31:31          677         1573
# 4               352594  2022-01-01 00:56:18          322         1398
# ...                ...                  ...          ...          ...
# 226726          579316  2022-04-29 23:52:18           27          914
# 226727          579317  2022-04-29 23:52:23          947         1281
# 226728          579318  2022-04-29 23:54:38          537         1636
# 226729          579319  2022-04-29 23:54:39            1          936
# 226730          579320  2022-04-29 23:56:44          798          364
#
#         TX_AMOUNT  x_customer_id  y_customer_id  mean_amount  std_amount  \
# 0          147.24      72.788816      63.746228    82.134163   41.067082
# 1           13.27      30.243124      74.364272    46.525169   23.262584
# 2           70.52      48.776456       1.331611    62.594881   31.297441
# 3           44.75      60.207552      59.042148    56.856095   28.428048
# 4           37.60       5.105306      33.126888    35.430997   17.715499
# ...           ...            ...            ...          ...         ...
# 226726      52.01      22.308163      95.274901    47.476911   23.738455
# 226727     136.96      60.740656      21.581337    86.840239   43.420120
# 226728      15.87      84.773933      56.139872    72.758371   36.379186
# 226729      35.13      42.365480      64.589411    46.570785   23.285393
# 226730      73.29      59.464768      92.864249    73.385943   36.692971
#
#         mean_nb_tx_per_day                                available_terminals  \
# 0                 1.917538  [173, 343, 439, 631, 640, 871, 935, 1170, 1260...
# 1                 1.675154  [295, 315, 499, 766, 1015, 1168, 1367, 1379, 1...
# 2                 3.956352  [27, 443, 454, 512, 676, 734, 1186, 1299, 1363...
# 3                 3.756383  [84, 103, 128, 314, 547, 797, 824, 983, 1075, ...
# 4                 3.787229  [89, 187, 269, 466, 503, 551, 606, 639, 710, 7...
# ...                    ...                                                ...
# 226726            3.385635  [302, 380, 450, 521, 525, 657, 719, 833, 850, ...
# 226727            3.217332  [76, 90, 121, 723, 829, 863, 915, 918, 933, 10...
# 226728            3.927457  [62, 169, 260, 335, 553, 618, 895, 951, 1025, ...
# 226729            3.567092  [5, 160, 242, 378, 431, 475, 571, 762, 876, 93...
# 226730            3.069443  [65, 99, 364, 401, 433, 545, 651, 672, 772, 84...
#
#         nb_terminals
# 0                 14
# 1                 11
# 2                 10
# 3                 19
# 4                 20
# ...              ...
# 226726            16
# 226727            19
# 226728            19
# 226729            20
# 226730            15
#
# [226731 rows x 12 columns]

# %%
df_test_merge = pd.merge(df_test_merge, df_ter, left_on='TERMINAL_ID', right_on='TERMINAL_ID')
df_test_merge
# Out:
#         TRANSACTION_ID          TX_DATETIME  CUSTOMER_ID  TERMINAL_ID  \
# 0               352590  2022-01-01 00:03:14          208          640
# 1               352591  2022-01-01 00:26:39          851          315
# 2               352592  2022-01-01 00:30:30          454           27
# 3               352593  2022-01-01 00:31:31          677         1573
# 4               352594  2022-01-01 00:56:18          322         1398
# ...                ...                  ...          ...          ...
# 226726          579316  2022-04-29 23:52:18           27          914
# 226727          579317  2022-04-29 23:52:23          947         1281
# 226728          579318  2022-04-29 23:54:38          537         1636
# 226729          579319  2022-04-29 23:54:39            1          936
# 226730          579320  2022-04-29 23:56:44          798          364
#
#         TX_AMOUNT  x_customer_id  y_customer_id  mean_amount  std_amount  \
# 0          147.24      72.788816      63.746228    82.134163   41.067082
# 1           13.27      30.243124      74.364272    46.525169   23.262584
# 2           70.52      48.776456       1.331611    62.594881   31.297441
# 3           44.75      60.207552      59.042148    56.856095   28.428048
# 4           37.60       5.105306      33.126888    35.430997   17.715499
# ...           ...            ...            ...          ...         ...
# 226726      52.01      22.308163      95.274901    47.476911   23.738455
# 226727     136.96      60.740656      21.581337    86.840239   43.420120
# 226728      15.87      84.773933      56.139872    72.758371   36.379186
# 226729      35.13      42.365480      64.589411    46.570785   23.285393
# 226730      73.29      59.464768      92.864249    73.385943   36.692971
#
#         mean_nb_tx_per_day                                available_terminals  \
# 0                 1.917538  [173, 343, 439, 631, 640, 871, 935, 1170, 1260...
# 1                 1.675154  [295, 315, 499, 766, 1015, 1168, 1367, 1379, 1...
# 2                 3.956352  [27, 443, 454, 512, 676, 734, 1186, 1299, 1363...
# 3                 3.756383  [84, 103, 128, 314, 547, 797, 824, 983, 1075, ...
# 4                 3.787229  [89, 187, 269, 466, 503, 551, 606, 639, 710, 7...
# ...                    ...                                                ...
# 226726            3.385635  [302, 380, 450, 521, 525, 657, 719, 833, 850, ...
# 226727            3.217332  [76, 90, 121, 723, 829, 863, 915, 918, 933, 10...
# 226728            3.927457  [62, 169, 260, 335, 553, 618, 895, 951, 1025, ...
# 226729            3.567092  [5, 160, 242, 378, 431, 475, 571, 762, 876, 93...
# 226730            3.069443  [65, 99, 364, 401, 433, 545, 651, 672, 772, 84...
#
#         nb_terminals  x_terminal_id  y_terminal_id
# 0                 14      74.170480      61.501572
# 1                 11      29.548229      73.160647
# 2                 10      49.157316       5.336255
# 3                 19      64.603026      60.509913
# 4                 20       8.895911      32.670126
# ...              ...            ...            ...
# 226726            16      24.294713      91.384388
# 226727            19      57.507017      21.478254
# 226728            19      87.668581      56.148648
# 226729            20      46.755005      66.694254
# 226730            15      57.327227      94.276258
#
# [226731 rows x 14 columns]

# %%
xx = df_test_merge.drop('TRANSACTION_ID', axis='columns')
xx = xx.drop('TX_DATETIME', axis='columns')
xx = xx.drop('available_terminals', axis='columns')

xx = xx.drop('mean_amount', axis='columns')
xx = xx.drop('std_amount', axis='columns')


# yy = df_test['TX_FRAUD']
xx
# Out:
#         CUSTOMER_ID  TERMINAL_ID  TX_AMOUNT  x_customer_id  y_customer_id  \
# 0               208          640     147.24      72.788816      63.746228
# 1               851          315      13.27      30.243124      74.364272
# 2               454           27      70.52      48.776456       1.331611
# 3               677         1573      44.75      60.207552      59.042148
# 4               322         1398      37.60       5.105306      33.126888
# ...             ...          ...        ...            ...            ...
# 226726           27          914      52.01      22.308163      95.274901
# 226727          947         1281     136.96      60.740656      21.581337
# 226728          537         1636      15.87      84.773933      56.139872
# 226729            1          936      35.13      42.365480      64.589411
# 226730          798          364      73.29      59.464768      92.864249
#
#         mean_nb_tx_per_day  nb_terminals  x_terminal_id  y_terminal_id
# 0                 1.917538            14      74.170480      61.501572
# 1                 1.675154            11      29.548229      73.160647
# 2                 3.956352            10      49.157316       5.336255
# 3                 3.756383            19      64.603026      60.509913
# 4                 3.787229            20       8.895911      32.670126
# ...                    ...           ...            ...            ...
# 226726            3.385635            16      24.294713      91.384388
# 226727            3.217332            19      57.507017      21.478254
# 226728            3.927457            19      87.668581      56.148648
# 226729            3.567092            20      46.755005      66.694254
# 226730            3.069443            15      57.327227      94.276258
#
# [226731 rows x 9 columns]

# %%
yy_pred = model.predict(xx)
yy_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 yy_pred = model.predict(xx)
#       2 yy_pred
#
# File c:\Program Files\Python312\Lib\site-packages\sklearn\linear_model\_base.py:351, in LinearClassifierMixin.predict(self, X)
#     337 """
#     338 Predict class labels for samples in X.
#     339
#    (...)
#     348     Vector containing the class labels for each sample.
#     349 """
#     350 xp, _ = get_namespace(X)
# --> 351 scores = self.decision_function(X)
#     352 if len(scores.shape) == 1:
#     353     indices = xp.astype(scores > 0, int)
#
# File c:\Program Files\Python312\Lib\site-packages\sklearn\linear_model\_base.py:332, in LinearClassifierMixin.decision_function(self, X)
#     329 check_is_fitted(self)
#     330 xp, _ = get_namespace(X)
# --> 332 X = self._validate_data(X, accept_sparse="csr", reset=False)
#     333 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     334 return xp.reshape(scores, (-1,)) if scores.shape[1] == 1 else scores
#
# File c:\Program Files\Python312\Lib\site-packages\sklearn\base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)
#     544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)
#     606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File c:\Program Files\Python312\Lib\site-packages\sklearn\base.py:535, in BaseEstimator._check_feature_names(self, X, reset)
#     530 if not missing_names and not unexpected_names:
#     531     message += (
#     532         "Feature names must be in the same order as they were in fit.\n"
#     533     )
# --> 535 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names seen at fit time, yet now missing:
# - Day
# - Day_of_week
# - Hour
# - Minute
# - Month
# - ...

# %%
yy_pred_df = pd.DataFrame(yy_pred, columns=['TX_FRAUD'])
yy_pred_df
# Out:
#         TX_FRAUD
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 226726         0
# 226727         0
# 226728         0
# 226729         0
# 226730         0
#
# [226731 rows x 1 columns]

# %%
class_names = {0:'Not Fraud', 1:'Fraud'}
print(yy_pred_df.TX_FRAUD.value_counts().rename(index = class_names))
# Out:
# TX_FRAUD
# Not Fraud    226731
# Name: count, dtype: int64

# %%
result = pd.concat([xx, yy_pred_df], axis=1)
result
# Out:
#         CUSTOMER_ID  TERMINAL_ID  TX_AMOUNT  x_customer_id  y_customer_id  \
# 0               208          640     147.24      72.788816      63.746228
# 1               851          315      13.27      30.243124      74.364272
# 2               454           27      70.52      48.776456       1.331611
# 3               677         1573      44.75      60.207552      59.042148
# 4               322         1398      37.60       5.105306      33.126888
# ...             ...          ...        ...            ...            ...
# 226726           27          914      52.01      22.308163      95.274901
# 226727          947         1281     136.96      60.740656      21.581337
# 226728          537         1636      15.87      84.773933      56.139872
# 226729            1          936      35.13      42.365480      64.589411
# 226730          798          364      73.29      59.464768      92.864249
#
#         mean_nb_tx_per_day  nb_terminals  x_terminal_id  y_terminal_id  \
# 0                 1.917538            14      74.170480      61.501572
# 1                 1.675154            11      29.548229      73.160647
# 2                 3.956352            10      49.157316       5.336255
# 3                 3.756383            19      64.603026      60.509913
# 4                 3.787229            20       8.895911      32.670126
# ...                    ...           ...            ...            ...
# 226726            3.385635            16      24.294713      91.384388
# 226727            3.217332            19      57.507017      21.478254
# 226728            3.927457            19      87.668581      56.148648
# 226729            3.567092            20      46.755005      66.694254
# 226730            3.069443            15      57.327227      94.276258
#
#         TX_FRAUD
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 226726         0
# 226727         0
# 226728         0
# 226729         0
# 226730         0
#
# [226731 rows x 10 columns]

# %%
result[result["TX_FRAUD"]==1]
# Out:
# Empty DataFrame
# Columns: [CUSTOMER_ID, TERMINAL_ID, TX_AMOUNT, x_customer_id, y_customer_id, mean_nb_tx_per_day, nb_terminals, x_terminal_id, y_terminal_id, TX_FRAUD]
# Index: []

# %%
result[result["TX_FRAUD"]==0]
# Out:
#         CUSTOMER_ID  TERMINAL_ID  TX_AMOUNT  x_customer_id  y_customer_id  \
# 0               208          640     147.24      72.788816      63.746228
# 1               851          315      13.27      30.243124      74.364272
# 2               454           27      70.52      48.776456       1.331611
# 3               677         1573      44.75      60.207552      59.042148
# 4               322         1398      37.60       5.105306      33.126888
# ...             ...          ...        ...            ...            ...
# 226726           27          914      52.01      22.308163      95.274901
# 226727          947         1281     136.96      60.740656      21.581337
# 226728          537         1636      15.87      84.773933      56.139872
# 226729            1          936      35.13      42.365480      64.589411
# 226730          798          364      73.29      59.464768      92.864249
#
#         mean_nb_tx_per_day  nb_terminals  x_terminal_id  y_terminal_id  \
# 0                 1.917538            14      74.170480      61.501572
# 1                 1.675154            11      29.548229      73.160647
# 2                 3.956352            10      49.157316       5.336255
# 3                 3.756383            19      64.603026      60.509913
# 4                 3.787229            20       8.895911      32.670126
# ...                    ...           ...            ...            ...
# 226726            3.385635            16      24.294713      91.384388
# 226727            3.217332            19      57.507017      21.478254
# 226728            3.927457            19      87.668581      56.148648
# 226729            3.567092            20      46.755005      66.694254
# 226730            3.069443            15      57.327227      94.276258
#
#         TX_FRAUD
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 226726         0
# 226727         0
# 226728         0
# 226729         0
# 226730         0
#
# [226731 rows x 10 columns]

# %%
import joblib

# save the model to disk
filename = 'C:/dataset/finalized_model.sav'
# joblib.dump(model, filename)

# load the saved model
model = joblib.load(filename)


# input = [[220,	828,	76.25]] #1  0
# input = [[679,	1893,	38.80]] #1  1
# input = [[311,	895,	60.12	]] #1   0
# input = [[2,	1365,	94.92	]] #1   0
# input = [[723,	1565,	84.04	]] #1   1
# input = [[	]] #1   0
# input = [[	]] #1   0
# input = [[	]] #1   0

df = pd.DataFrame(data=input, columns=["CUSTOMER_ID", "TERMINAL_ID", "TX_AMOUNT"])
# df
df= pd.merge(df, df_cust, left_on='CUSTOMER_ID', right_on='CUSTOMER_ID')
# df
df= pd.merge(df, df_ter, left_on='TERMINAL_ID', right_on='TERMINAL_ID')


xx = df.drop('available_terminals', axis='columns')
xx = xx.drop('mean_amount', axis='columns')
xx = xx.drop('std_amount', axis='columns')

# xx
display(xx)

y_pred2 = model.predict(xx)
y_pred2

display(y_pred2[0])

print( "legitimate" if (y_pred2[0]==0) else "fraudulent" )
# Out:
#    CUSTOMER_ID  TERMINAL_ID  TX_AMOUNT  x_customer_id  y_customer_id  \
# 0          723         1565      84.04      97.021294      71.748573
#
#    mean_nb_tx_per_day  nb_terminals  x_terminal_id  y_terminal_id
# 0            2.780352            16      97.325255      73.758851
# 0
# legitimate
